# %% [markdown]
# # ***AI-Assisted Programming Session - "We Will Always Have Paris"*** 🌳💻
#
# **Bioinformatics in Health Sciences 2025**
#
# **12 Feb 2025**
#
# Link to interactive version: https://colab.research.google.com/github/nunososorio/bhs/blob/main/bhs2025_a2.ipynb

# %% [markdown]
# # Let's understand and test some code! 🧐

# %% [markdown]
# Let's begin by exploring a dataset containing information about all the trees in Paris. 🌳🌳🌳
# Run the code below to download the dataset to Colab and your computer. ⬇️

# %%
# Install the google.colab library (if not already installed)
# !pip install google-colab

# Download the file using wget
# !wget https://raw.githubusercontent.com/nunososorio/medicaldatascience/main/les-arbres.xlsx

# Import the files module from google.colab
from google.colab import files

# Download the file to your local computer
files.download('les-arbres.xlsx')

# %%
from IPython.display import HTML; HTML("""<div class="sketchfab-embed-wrapper"> <iframe title="Trees of Paris" frameborder="0" allowfullscreen mozallowfullscreen="true" webkitallowfullscreen="true" allow="autoplay; fullscreen; xr-spatial-tracking" xr-spatial-tracking execution-while-out-of-viewport execution-while-not-rendered web-share src="https://sketchfab.com/models/18b6147712854200bdbc5c5424e3c0dd/embed" width="100%" height="800px"> </iframe> </div>""")
# Out:
# <div class="sketchfab-embed-wrapper"> <iframe title="Trees of Paris" frameborder="0" allowfullscreen mozallowfullscreen="true" webkitallowfullscreen="true" allow="autoplay; fullscreen; xr-spatial-tracking" xr-spatial-tracking execution-while-out-of-viewport execution-while-not-rendered web-share src="https://sketchfab.com/models/18b6147712854200bdbc5c5424e3c0dd/embed" width="100%" height="800px"> </iframe> </div>

# %% [markdown]
# This model, titled 'Trees of Paris', was generously created and shared by Loïc Norgeot under a CC Attribution license.
#
# Technical Details: This visualization combines open data on Parisian trees and public lights, superimposing their heights and light temperatures onto an exaggerated digital elevation model interpolated from SRTM data using Python. The 25 most common tree species are color-coded.

# %% [markdown]
# ## Open the Excel file (or any other program you prefer) to explore the data. Answer these questions based on the file:
# 1.  ***How many trees are there in Paris?***🌳
# 2.  ***What is the height (in meters) of the tallest tree?*** 📏
# 3.  ***What is the circumference (in cm) of the thickest tree?*** 🌳
# 4.  ***What is the average size of the trees in Paris?*** 📏
# 5.  ***What is the average circumference of the trees in Paris?*** 📏

# %% [markdown]
# Now, let's achieve the same results using Python code and AI assistance! 🤖 Ask your favorite LLM (Large Language Model) this: "*Generate python code to import pandas, read an Excel file named 'les-arbres.xlsx' into a DataFrame, and print the summary statistics of the data using describe()*" You can simply paste the prompt in the cell below in "generate with AI".

# %% [markdown]
# Explore AI explanations and external resources to **understand the code's functionality and the significance of the results**. Did you obtain similar results in Excel and Python? Which approach proved to be easier, more effective, and reproducible?  🤔

# %% [markdown]
# ## Let's try something harder! 🧐
# "Arrondissement" is a French term referring to an administrative district. Paris has 20 arrondissements, spiraling outward from the city center. **Which district has the most trees?** 🌲Use Excel and try to answer this question.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This map of Paris arrondissements was created by Thomas Steiner. It is licensed under the GNU Free Documentation License and the Creative Commons Attribution-Share Alike 3.0 Unported license.

# %% [markdown]
# ## Now, prompt the AI with this: "*Analyze the df DataFrame (containing tree data for Paris, with an 'ARRONDISSEMENT' column) using Pandas. Count the number of trees per arrondissement, sort the counts in descending order, store the result in arrondissement_counts, and print it. Assume df is pre-loaded.*"

# %% [markdown]
# **🕵️‍♀️ Use AI explanations and external resources to dissect each line and uncover its purpose. Decipher the results and understand their meaning in the context of the data. Consider these questions: Is every line of code essential? Could alternative approaches achieve the same outcome? 🤔 Feel free to test improvements!**

# %% [markdown]
# Compare the results you obtained with and the 3D visualization model. You can also use the VR googles to better view the model.

# %% [markdown]
# ### Now, try to adapt the code to count the types of trees by their common name (**'LIBELLE FRANCAIS'**).  ***Do this WITHOUT AI assistance*** 🤓 – test your coding skills!

# %%
# Type your code here

# %% [markdown]
# <h2>Explore Different Approaches:</h2>
#
# <h3>1. Direct Print:</h3>
# <pre>
# <code>
# print(df['LIBELLE FRANCAIS'].value_counts())
# </code>
# </pre>
#
# <h3>2. Explicit Sort:</h3>
# <pre>
# <code>
# print(df['LIBELLE FRANCAIS'].value_counts().sort_values(ascending=False))
# </code>
# </pre>
#
# <h3>3. Using a Variable:</h3>
# <pre>
# <code>
# name_counts = df['LIBELLE FRANCAIS'].value_counts()
# name_counts
# </code>
# </pre>

# %%
# Type your code here

# %% [markdown]
# <h3>🤔 Consider these questions:</h3>
# <ul>
#     <li>Do all of these code snippets produce the same output?</li>
#     <li>Is there any practical difference in using one approach over another in this case?</li>
#     <li>Is <code>print()</code> a function or a method? Is it part of standard Python or a specific library like pandas?</li>
#     <li>What about <code>value_counts()</code> and <code>sort_values()</code>? Are they functions or methods? Is it part of standard Python or a specific library like pandas?</li>
# </ul>

# %% [markdown]
# ## You now want to generate an interactive map pinpointing each "Sophora" tree.
#  You have one problem: the latitude and longitude are combined in one column geo_point_2d... 🗺️📍Since you have a large amount of data you need to use and efficent library and map representation. Try this prompt: "Write a Python script using plotly.express to create a scatter_mapbox visualization of 'Sophora' trees in Paris from 'les-arbres.xlsx'. Extract latitude and longitude from the 'geo_point_2d' column, set hover data to 'LIBELLE FRANCAIS', and mapbox style 'carto-positron'."

# %% [markdown]
# **🕵️‍♀️ Use AI explanations and external resources to dissect each line and uncover its purpose. Decipher the results and understand their meaning in the context of the data. Consider these questions: Is every line of code essential? Could alternative approaches achieve the same outcome? 🤔 Feel free to test improvements!**

# %% [markdown]
# ## Now let's put our skills to good use!
#
# Sara is planning a holiday to Paris in early summer. This time of year, unfortunately, coincides with the flowering period of *Zanthoxylum* trees. Sara has a rare and severe allergy specifically to the pollen of these trees. *To help her manage her allergy during her trip, could you please investigate whether Zanthoxylum trees are found in Paris and identify the specific districts she should avoid, if possible?* 🤧
#
# ***Use python and AI assistance and the prompts you think will be most effective.***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Image generated with Dall-E

# %% [markdown]
# **🕵️‍♀️ Use AI explanations and external resources to dissect each line and uncover its purpose. Decipher the results and understand their meaning in the context of the data. Consider these questions: Is every line of code essential? Could alternative approaches achieve the same outcome? 🤔 Feel free to test improvements!**

# %% [markdown]
# ## ***Advanced Exercises (optional)*** 🏆

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 🐼 Data Processing with Python: Example of Transcriptomics Dataframes 🧬

# %% [markdown]
# ## Task: Creating a Gene Count Matrix from Multiple DataFrames
#
# **Problem:** Transcriptomic analyses often require a gene count matrix, where genes are in rows and sample names in columns. We have raw sequencing data processed into separate DataFrames for each sample. We need to combine these into a single count matrix.
#
# **Details:**
#
# * Each sample's data is stored in a separate DataFrame within the file `GSM3711336.zip`.
# * The relevant gene read counts are found in the "Unique gene reads" column of each DataFrame.
# * **The goal is to create a single count matrix with genes as rows and sample names as columns.** This matrix will be used for downstream transcriptomic analyses.
#
# **In summary:** You have multiple spreadsheets, each representing a different patient's gene expression data. You want to create a single master spreadsheet that summarizes the gene counts for all patients, with genes listed down the side and patient names across the top.

# %%
import zipfile
from google.colab import files
# !wget -q https://github.com/nunososorio/medicaldatascience/raw/main/GSM3711336.zip
with zipfile.ZipFile('GSM3711336.zip', 'r') as zip_ref:
    zip_ref.extractall()

# Download the Zip file
files.download('GSM3711336.zip')

# %% [markdown]
# ## Now let's use Python programming to automate this task.
#
# 1. Let's start by reading the files with the pandas 🐼 library. Since the file is in xlsx format, we will have to use the command `pd.read_excel`

# %%
import pandas as pd

# %%
wt1_nt = pd.read_excel("GSM3711329_WT1_NT.xlsx")
wt1_nt

# %% [markdown]
# We could import each of the files this way, but if we use a loop, we can be more efficient.

# %% [markdown]
# ### Loops:
#
# 📝 Loops are used to execute a block of code repeatedly. The most common type is the **"for loop"**:
# - A **"for loop"** is used to iterate over a sequence of items, such as a list of filenames or a range of numbers. The general syntax is "for variable in sequence:", where the variable takes on each value in the sequence, one at a time, and the block of code following the "for" statement is executed for each value.
# - With a **"for loop"**, we can load all `*.xlsx` files automatically without having to worry about creating a command for each file.

# %% [markdown]
# **Part 1:** Read and Combine Multiple Excel Files
#
# **Prompt:**"Write Python code that uses pandas, glob, and os to:
# 1. Read all .xlsx files in the current directory into separate pandas DataFrames.
# 2. Add a 'Sample' column to each DataFrame with the filename as the sample name.
# 3. Store all DataFrames in a list named 'dfs'.
# 4. Print the list of DataFrames 'dfs'."

# %% [markdown]
# The `dfs` is a list containing all the DataFrames, each corresponding to the .xlsx files in the directory.
#
# To create the count matrix, one of the simplest ways is to:
# * Use the Pandas 🐼 `concat` to concatenate all the DataFrames in the list into a single DataFrame.
# * Use the Pandas 🐼 `pivot_table` to generate the matrix, setting 'Name' as the index (rows) and 'Sample' as the column names, filling the new table with values from the 'Unique gene reads' column.

# %% [markdown]
# **Part 2:** Create the count matrix
#
# **Prompt:** "Generate Python code using pandas to:
# 1. Combine a list of DataFrames named 'dfs' into a single DataFrame called 'combined_df' using `pd.concat`.
# 2. Create a count matrix named 'matrix' from 'combined_df' using `pivot_table`.
#     - Set 'Name' as the index (rows).
#     - Set 'Sample' as the columns.
#     - Use 'Unique gene reads' as the values.
#     - Fill any missing values with NA.
# 3. Display the resulting 'matrix'."

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Processing with R: Differential Expression Analysis of Transcriptomic Data Using EdgeR and the Impact of Different Normalization Methods 🧬🔬📊

# %% [markdown]
# 📈 In the field of RNA-seq data analysis, scaling-based normalization methods are commonly used, such as:
#
# 1. **TMM (Trimmed Mean of M-values)**: This method estimates scale factors between samples (M-values), which minimize log-fold changes between samples for the majority of genes. TMM is based on the assumption that most genes are not differentially expressed.
#
# 2. **RLE (Relative Log Expression)**: This method calculates the scale factor as the median of ratios, for each gene, of its read counts to the geometric mean of read counts for that gene across all samples.
#
# 3. **TMMwsp (Weighted Trimmed Mean of M-values with Singleton Pairing)**: This method is a variant of TMM that is designed to work better for data with a high proportion of zeros. In the TMM method, genes that have zero count in any sample are ignored when comparing sample pairs. In the TMMwsp method, the positive counts of such genes are reused to increase the number of features by which samples are compared.

# %%
# Download the file
url <- "https://raw.githubusercontent.com/nunososorio/medicaldatascience/main/counts.csv"
filename <- "counts.csv"
download.file(url, destfile = filename)

# %% [markdown]
# **Part 1:** Install and Load Necessary Libraries
#
# **Prompt:** "Generate R code to install and load the 'edgeR' library from Bioconductor. Include checks to see if the packages are already installed, and install them if necessary."

# %% [markdown]
# **Part 2:** Data Input and Preprocessing
#
# **Prompt:** "The file 'counts.csv' has been downloaded.  It contains gene expression data. The first column contains gene IDs, and the remaining columns represent samples. The samples are grouped into two conditions: 'control' (first 3 samples) and 'knockout' (last 3 samples). Generate R code to read the data from 'counts.csv' and create a DGEList object using edgeR.""

# %%
dge

# %% [markdown]
# **Part 3:** Normalization (TMM and RLE)
#
# **Prompt:** "Generate R code to perform normalization on the DGEList object (created in Part 2) using two different methods: TMM (Trimmed Mean of M-values) and RLE (Relative Log Expression). Store the normalized DGEList objects in separate variables (e.g., `y_tmm`, `y_rle`)."

# %% [markdown]
# **Part 4:** Differential Expression Analysis (for TMM and RLE)
#
# **Prompt:** "Generate R code to perform differential expression analysis using edgeR's `glmQLFit` and `glmQLFTest` functions (using a quasi-likelihood F-test) for *each* of the normalized DGEList objects created in Part 3 (`y_tmm`, `y_rle`). Extract the results table for each analysis, including log2 fold change (logFC), logCPM, p-values, and adjusted p-values (FDR) using the Benjamini-Hochberg method. Store the results tables in separate variables (e.g., `results_tmm`, `results_rle`)."

# %% [markdown]
# **Part 5:** Volcano Plot Generation (for TMM and RLE)
#
# **Prompt:** "Generate R code to create a volcano plot for *each* of the results tables from Part 4 (`results_tmm`, `results_rle`). Plot -log10(FDR) on the y-axis and logFC on the x-axis. Highlight genes with an FDR less than 0.05 and an absolute logFC greater than 1. Use different colors for up-regulated, down-regulated, and non-significant genes. Add a title to each plot indicating the normalization method used (e.g., 'Volcano Plot (TMM)'). Add clear axis labels."

# %% [markdown]
# **Part 6:** Extract Top DE Genes (for TMM and RLE)
#
# **Prompt:** "Generate R code to extract the top differentially expressed (DE) genes from *each* of the results tables in Part 4 (`results_tmm`, `results_rle`). Define 'top DE genes' as those with an FDR less than 0.05 and an absolute logFC greater than 1. Store the gene IDs of the top DE genes for each method in separate character vectors (e.g., `top_genes_tmm`, `top_genes_rle`)."

# %% [markdown]
# **Part 7:** DEG Comparison (TMM and RLE)
#
# **Prompt:**"Generate R code to compare the lists of differentially expressed (DE) genes obtained from the TMM and RLE normalization methods (assuming `top_genes_tmm` and `top_genes_rle` character vectors exist from previous steps, containing gene IDs). 1.  Intersection: Find the genes that are DE in both TMM and RLE (the intersection of the two sets). Count the number of these genes and print the count with a descriptive label.  Print the first 10 gene IDs of the intersection. 2. Unique to TMM: Find the genes that are DE only in TMM (present in the TMM list but not in the RLE list). Print the first 10 gene IDs. 3. Unique to RLE: Find the genes that are DE *only* in RLE (present in the RLE list but not in the TMM list). Print the first 10 gene IDs. Use appropriate set operations (`intersect`, `setdiff`) for these comparisons."

# %% [markdown]
# # 🌐 Programmatic Access to Bioinformatics Databases
#
# 🤔 Programmatic access? Why? Isn't it much easier to use a browser?
#
# Programmatic access to databases has several advantages:
#
# *   **Automation:** Programmatic access allows the automation of repetitive tasks. For example, if you need to extract the same data from different parts of a database, a script can do it more efficiently than a human using a browser.
# *   **Integration:** Extracted data can be easily integrated with other parts of your data analysis pipeline. For example, you can extract data, process it, and visualize it using the same script.
# *   **Reproducibility:** Programmatic access ensures that the data extraction process is reproducible. This is especially important in science, where the ability to reproduce results is fundamental.
# *   **Customization:** With programmatic access, the user has more control over what they are doing. You can customize the script to meet your specific needs.
#
# In summary, while using a browser may be easier for simple, one-time tasks, programmatic access offers greater flexibility and control, especially when dealing with complex and repetitive tasks, as is typically the case in Bioinformatics.

# %% [markdown]
# ## Let's Explore ChEMBL: A Database for Chemical Compounds and Drugs 🐍💻
#
# Using databases is crucial in the Target-to-Hit and Hit-to-Lead stages of drug discovery. These databases provide a wealth of information about potential drug targets and the compounds that can interact with them. Accessing and analyzing this data can aid in identifying potential new drugs. 🧪🔬
#
# ChEMBL is a manually curated database containing a collection of bioactive molecules with properties favorable for use as drugs. It brings together chemical, bioactivity, and genomic data to aid in translating genomic information into effective new drugs. 🧬💡
#
# The `chembl_webresource_client` is a Python module for accessing ChEMBL data. 🐍📦
#
# Let's start by installing and loading the module:

# %%
# !pip install chembl_webresource_client
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # 🚀 Scenario-based Exercise
#
# **Scenario**: You’re a researcher 🔬 involved in the exciting world of drug discovery and development. You’ve just received a recently synthesized compound from a collaborating chemical lab. The compound was sent via mail 📬, and intriguingly, it only included a printed image of the structure of the compound.
#
# **Your Mission**: Your task, should you choose to accept it, involves a few critical steps:
# 1. Convert the structure diagram to a SMILES string.
# 2. Search the ChEMBL database using the SMILES string. **Access the databases programmatically**.
# 3. Determine if the compound already exists in the database and if it has relevant annotation.
#
# Remember, the goal of these exercises is to familiarize you with accessing drug-related databases programmatically. This skill is crucial for reproducible and large-scale analysis in the steps of drug discovery.
#
# So, are you ready to embark on this journey? Let's dive in! 💻🎯
#
# This is the image of the compound:
#
# ![cpdX.png](data:image/png;base64,...)

# %% [markdown]
# First step: Convert the Kekulé diagram to a SMILES string. You can use several different software for that, including:
# https://cactus.nci.nih.gov/cgi-bin/osra/index.cgi

# %% [markdown]
# When you got the SMILES ou can use it to query ChEMBL database using the pyton module. Write or generate code to:
# *   Filter the ChEMBL database for molecules matching the provided SMILES string.
# *   Create a Pandas DataFrame containing the results.
# *   Display the DataFrame in the Colab output.

# %% [markdown]
# Copyright © 2025 Nuno S. Osório. All rights reserved.
